// %% [markdown]
// # Final Exam Tester

// %%
// def fun4(x: Int): Int = x match {
//     case y if y >= 0 => y - 10
//     case y if y <= 0 => y + 10
// }

// def fun2(x: Int): Int = x match {
//     case y if y >= 0 => y + 10
//     case _ => x - 10
// }

// def fun3(x: Int): Int = x match {
//     case y if y >= 0 => y + 10
//     case _ => z - 10
// }

// def fun1(x: Int): Int = {
//     if(x <= 20) { 45 }
// }

// val l = List(1, 2, 3, 4, 5, 6, 7, 8)
// val lst1 = List(1, 2, 3, 4, 5, 6, 7, 8)
// val lst2 = List(1, 2, 3, 4, 5, 6, 7, 8)

// l.filter(_ % 2 == 0) 

// l.foldLeft(0) { (acc, elt) => acc + elt * elt}

// l.map(x => x * x)

// lst1.zip(lst2).foldLeft(0){ (acc, elt) => acc + elt._1 * elt._2}

// var y = 15
// def f(y:Int):Int = y - 30
// val z = false
// y = 20
// val x = -20

// print((x < y) && x)

// var y = 10
// def f(x: Int): Int = { x - 10 }
// y = 20
// def g(y: Int): Int = { f(y) }

// print(g(y))
// Maybe 1
// NOT 2
// NOT 3
// YES 4
// NOT 5
// NOT 6 because y doesn't exist?

// def f(x: Int):Int = x - 10
// def g(y: Int):Int = f(y) - 20

// g(y) + 5

// def infLoop(x: Int):Nothing = infLoop(x + 1)

// def f(x: Int):Int = x - 10
// def g(y: Int):Boolean = f(y) >= 20

// g(y) + 5

// /* The parent class of them all */
// abstract class Animal 

// /* some traits */
// trait SwimsInWater
// trait WalksInLand

// /* some classes */
// class Reptile extends Animal
// class Fish extends Animal with SwimsInWater
// class Amphibian extends Animal with SwimsInWater with WalksInLand
// class Frog extends Amphibian
// class Nemo extends Fish
// // .. other class definitions are possible .. 

// /* some functions */
// def analyzeSwimSpeed[T<:Animal with SwimsInWater] ( T: Animal): Double = { ??? } 
// def analyzeLandSpeed[T] ( T: Animal) : Double = { ??? } 
// def printAnimalGenusAndSpecies[T] ( T: Animal ) : String = { ??? }

// def myfun ( x: Int, y: String) : Int = {
//     if (x <= 0) {
//         x + y.length
//     } else {
//         myfun( x - 2 ,  "world" ) - myfun( x - 1, "hello") 
//     }
// }

// def myfun_cps[T]( x : Int, y : String, k : Int => T) : T = {
//     if (x <= 0) {
//         k(x + y.length)
//     } else {
//         myfun_cps(x - 2, "world", (v1) => { myfun_cps( x - 1, "hello", (v2) => { k(v1 - v2) } ) } )
//     }
// }

// myfun(1,"string")
// val identity: Int => Int = y => y
// myfun_cps(1, "string", identity)

// false && error
// false && false
// error && true
// 

// if e1 can be evaluated and it is a boolean AND if e2 can be evaluated and it is a boolean, then e1 && e2 = v1 && v2
// if e1 can be evaluated but it is NOT a boolean, then e1 && e2 = error
// if e1 can be evaluated and it is a boolean, AND if e2 can be evaluated and it is NOT a boolean, then e1 && e2 = error

// e1 = (10 >= 2) is a boolean

var z = 45
// Out:
// cmd20.sc:1: not found: value Reference
// val z$value = new _root_.almond.api.internal.Modifiable(Reference(45))
//                                                         ^cmd20.sc:9: not found: value z
//   .printOnChange(z, "z", _root_.scala.None, _root_.scala.Some(z$value.onChange), _root_.scala.None)) }
//                  ^Compilation Failed
// Compilation Failed
